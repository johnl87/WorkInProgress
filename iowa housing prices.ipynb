# %%
import keras #ML Library
import tensorflow as tf
import numpy as np #Mathematics Library
import pandas as pd #Data-handling Library
import matplotlib.pyplot as plt #Used to graph our results

# %%
#If you want to import from Drive
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/IowaHousingPrices.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
squareFeet = df[['SquareFeet']].values #x value
salePrice = df[['SalePrice']].values #y value

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(1, input_shape=(1,)))
model.compile(tf.keras.optimizers.Adam(lr=0.5), 'mean_squared_error')

model.fit(squareFeet,salePrice, epochs=30, batch_size=10)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 146/146 [==============================] - 1s 1ms/step - loss: 22815373312.0000
# Epoch 2/30
# 146/146 [==============================] - 0s 2ms/step - loss: 6807674880.0000
# Epoch 3/30
# 146/146 [==============================] - 0s 2ms/step - loss: 3534774784.0000
# Epoch 4/30
# 146/146 [==============================] - 0s 2ms/step - loss: 3200942336.0000
# Epoch 5/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3184199936.0000
# Epoch 6/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3181836800.0000
# Epoch 7/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3181006848.0000
# Epoch 8/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3184387840.0000
# Epoch 9/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3186311424.0000
# Epoch 10/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3187029248.0000
# Epoch 11/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3190038528.0000
# Epoch 12/30
# 146/146 [==============================] - 0s 2ms/step - loss: 3186806272.0000
# Epoch 13/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3185660416.0000
# Epoch 14/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3185142528.0000
# Epoch 15/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3190497280.0000
# Epoch 16/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3186542080.0000
# Epoch 17/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3183838720.0000
# Epoch 18/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3185837056.0000
# Epoch 19/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3192527104.0000
# Epoch 20/30
# 146/146 [==============================] - 0s 2ms/step - loss: 3199911424.0000
# Epoch 21/30
# 146/146 [==============================] - 0s 2ms/step - loss: 3193039360.0000
# Epoch 22/30
# 146/146 [==============================] - 0s 2ms/step - loss: 3182429184.0000
# Epoch 23/30
# 146/146 [==============================] - 0s 2ms/step - loss: 3184955904.0000
# Epoch 24/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3190187264.0000
# Epoch 25/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3188980224.0000
# Epoch 26/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3194194176.0000
# Epoch 27/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3192466944.0000
# Epoch 28/30
# 146/146 [==============================] - 0s 1ms/step - loss: 3194206720.0000
# Epoch 29/30
# 146/146 [==============================] - 0s 2ms/step - loss: 3184536320.0000
# Epoch 30/30
# 146/146 [==============================] - 0s 2ms/step - loss: 3193216768.0000

# %%
#Plot datapoints
df.plot(kind='scatter',
       x='SquareFeet',
       y='SalePrice', title='Housing Prices and Square Footage of Iowa Homes')


y_pred = model.predict(squareFeet) #The predicted housing price based on square feet

#Plot the linear regression line
plt.plot(squareFeet, y_pred, color='red')
